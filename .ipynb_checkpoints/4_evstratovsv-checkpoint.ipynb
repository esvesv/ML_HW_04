# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, HuberRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
df = pd.read_csv('train.csv')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
missing = df.isna().mean() * 100
missing = missing[missing > 0]
missing.sort_values(inplace=True)
missing
# Out:
# Electrical       0.068493
# MasVnrType       0.547945
# MasVnrArea       0.547945
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtFinType1     2.534247
# BsmtExposure     2.602740
# BsmtFinType2     2.602740
# GarageCond       5.547945
# GarageQual       5.547945
# GarageFinish     5.547945
# GarageType       5.547945
# GarageYrBlt      5.547945
# LotFrontage     17.739726
# FireplaceQu     47.260274
# Fence           80.753425
# Alley           93.767123
# MiscFeature     96.301370
# PoolQC          99.520548
# dtype: float64

# %%
df.drop(['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu'], axis=1, inplace=True)

# %%
df.shape
# Out:
# (1460, 76)

# %%
df.dropna(axis=0, inplace=True)

# %%
df.shape
# Out:
# (1094, 76)

# %%
numerical_features = [x for x in df.columns if df.dtypes[x] != 'object']
numerical_features.remove('Id')
# numerical_features

# %%
categorical_features = [x for x in df.columns if df.dtypes[x] == 'object']

# %%
for feature in categorical_features:
    df[feature] = df[feature].astype('category')
    df[feature] = df[feature].cat.codes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1094 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1094 non-null   int64
#  1   MSSubClass     1094 non-null   int64
#  2   MSZoning       1094 non-null   int8
#  3   LotFrontage    1094 non-null   float64
#  4   LotArea        1094 non-null   int64
#  5   Street         1094 non-null   int8
#  6   LotShape       1094 non-null   int8
#  7   LandContour    1094 non-null   int8
#  8   Utilities      1094 non-null   int8
#  9   LotConfig      1094 non-null   int8
#  10  LandSlope      1094 non-null   int8
#  11  Neighborhood   1094 non-null   int8
#  12  Condition1     1094 non-null   int8
#  13  Condition2     1094 non-null   int8
#  14  BldgType       1094 non-null   int8
#  15  HouseStyle     1094 non-null   int8
#  16  OverallQual    1094 non-null   int64
#  17  OverallCond    1094 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotArea', 'Street', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
for feature in df.columns[1: -1]:
    plt.figure(figsize=(10, 10))
    plt.scatter(df[feature], df.SalePrice)
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
# Out:
# C:\Users\evstr\AppData\Local\Temp\ipykernel_11096\3485282158.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10, 10))

# %%
corr = df.drop(['Id', 'Exterior2nd', 'GarageArea', '1stFlrSF', 'GarageYrBlt'], axis=1).corr()

# %%
corr[(corr.SalePrice > 0.6) | (corr.SalePrice < (-0.6))]['SalePrice'].index
# Out:
# Index(['OverallQual', 'ExterQual', 'BsmtQual', 'TotalBsmtSF', 'GrLivArea',
#        'KitchenQual', 'GarageCars', 'SalePrice'],
#       dtype='object')

# %%
corr.ExterQual
# Out:
# MSSubClass      -0.029122
# MSZoning         0.195937
# LotArea         -0.050336
# Street           0.062956
# LotShape         0.143109
#                    ...
# MoSold          -0.025471
# YrSold          -0.037885
# SaleType         0.075096
# SaleCondition   -0.196357
# SalePrice       -0.648023
# Name: ExterQual, Length: 70, dtype: float64

# %%
sns.set_theme()

# Load the example flights dataset and convert to long-form
# flights_long = sns.load_dataset("flights")
# flights = flights_long.pivot("month", "year", "passengers")
# print(flights_long)
# print(flights)
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(corr.loc[['OverallQual', 'YearBuilt', 'YearRemodAdd', 'ExterQual', 'BsmtQual',
       'TotalBsmtSF', 'GrLivArea', 'FullBath', 'KitchenQual', 'TotRmsAbvGrd',
       'GarageFinish', 'GarageCars', 'SalePrice'], ['OverallQual', 'YearBuilt', 'YearRemodAdd', 'ExterQual', 'BsmtQual',
       'TotalBsmtSF', 'GrLivArea', 'FullBath', 'KitchenQual', 'TotRmsAbvGrd',
       'GarageFinish', 'GarageCars', 'SalePrice']], fmt='d', cbar=False)
# Out:
# <AxesSubplot:>

# %%
['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'SalePrice']
# Out:
# ['OverallQual',
#  'YearBuilt',
#  'YearRemodAdd',
#  'TotalBsmtSF',
#  'GrLivArea',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'GarageCars',
#  'SalePrice']

# %% [raw]
# Exterior2nd GarageArea 1stFlrSF GarageYtBlt

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
X = np.array(df.drop(['Id', 'SalePrice'], axis=1))
# X = np.array(df[['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars']])
X.shape
# Out:
# (1094, 74)

# %%
y = np.array(df['SalePrice'])
y.shape
# Out:
# (1094,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = LinearRegression()
model.fit(X_train, y_train)

print(f'Точность на тренировочных данных: {model.score(X_train, y_train)}')
print(f'Точность на тестовых данных: {model.score(X_test, y_test)}')
# Out:
# Точность на тренировочных данных: 0.8561906044108005
# Точность на тестовых данных: 0.7683980463491801

# %%
for feature, w in zip(df.columns[1: -1], model.coef_):
    print(f'{feature}: {w}')
# Out:
# MSSubClass: -5491.852118165522
# MSZoning: 270.7550369793844
# LotFrontage: -3966.2787168345967
# LotArea: 4649.583508364159
# Street: 2746.026009571582
# LotShape: -1577.1534670360415
# LandContour: 2477.3267470580463
# Utilities: -4.952128569307842e+16
# LotConfig: 578.8899366099158
# LandSlope: -240.0
# Neighborhood: 2273.0
# Condition1: 792.5
# Condition2: 123.75
# BldgType: -3292.0
# HouseStyle: -2726.0
# OverallQual: 13699.75
# OverallCond: 4693.5
# YearBuilt: 6638.0
# YearRemodAdd: -290.0
# RoofStyle: 3643.5
# RoofMatl: 4562.0
# Exterior1st: -1110.0
# Exterior2nd: -1065.0
# MasVnrType: 3986.0
# MasVnrArea: 6487.0
# ExterQual: -8329.5
# ExterCond: 626.5
# Foundation: -187.0
# BsmtQual: -8180.0
# BsmtCond: 1387.0
# BsmtExposure: -4522.0
# BsmtFinType1: -3396.0
# BsmtFinSF1: 3.1103438224832784e+16
# BsmtFinType2: -817.5
# BsmtFinSF2: 1.0560837406557334e+16
# BsmtUnfSF: 2.967249806012908e+16
# TotalBsmtSF: -2.7827430403765424e+16
# Heating: -107.875
# HeatingQC: -99.0
# ...

# %%
model = Lasso()
model.fit(X_train, y_train)
print(f'Точность на тренировочных данных: {model.score(X_train, y_train)}')
print(f'Точность на тестовых данных: {model.score(X_test, y_test)}')
# Out:
# Точность на тренировочных данных: 0.8561680010002457
# Точность на тестовых данных: 0.7683129790850278

# %%
for feature, w in zip(['OverallQual', 'ExterQual', 'BsmtQual', 'BsmtFinSF1', 'TotalBsmtSF', 'GrLivArea', 'KitchenQual', 'GarageArea'], model.coef_):
    print(f'{feature}: {w}')
# Out:
# OverallQual: 24401.04864638705
# ExterQual: 8659.775679391616
# BsmtQual: 7466.4111914243485
# BsmtFinSF1: 19381.755008310876
# TotalBsmtSF: 34563.194413234865
# GrLivArea: -9287.609224325097
# KitchenQual: 1140.2408189777836
# GarageArea: 6717.354532584789

# %%
model = Ridge(alpha=1300)
model.fit(X_train, y_train)
print(f'Точность на тренировочных данных: {model.score(X_train, y_train)}')
print(f'Точность на тестовых данных: {model.score(X_test, y_test)}')
# Out:
# Точность на тренировочных данных: 0.8114927715872434
# Точность на тестовых данных: 0.7660383502382919

# %%
model = ElasticNet(alpha=2)
model.fit(X_train, y_train)
print(f'Точность на тренировочных данных: {model.score(X_train, y_train)}')
print(f'Точность на тестовых данных: {model.score(X_test, y_test)}')
# Out:
# Точность на тренировочных данных: 0.8279833162528409
# Точность на тестовых данных: 0.7755763799799934

# %%
model = HuberRegressor()
model.fit(X_train, y_train)
print(f'Точность на тренировочных данных: {model.score(X_train, y_train)}')
print(f'Точность на тестовых данных: {model.score(X_test, y_test)}')
# Out:
# Точность на тренировочных данных: 0.8156852546871978
# Точность на тестовых данных: 0.7617763090956494
